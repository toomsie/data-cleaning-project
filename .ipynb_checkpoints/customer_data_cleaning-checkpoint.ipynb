# %%
import pandas as pd

df = pd.read_csv("messy_customer.csv")

# %%
df.head()
# Out:
#      Customer         Phone      Product  Price
# 0  john smith  07123 456789    screw 5mm    0.1
# 1  SMITH JOHN    7123456789   5 mm screw    0.1
# 2     J Smith   07123456789  Screw (5mm)    0.1
# 3  mary jones  07222 333444    bolt 10mm    0.2
# 4  Mary Jones   07222333444    10mm bolt    0.2

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Customer  5 non-null      str
#  1   Phone     5 non-null      str
#  2   Product   5 non-null      str
#  3   Price     5 non-null      float64
# dtypes: float64(1), str(3)
# memory usage: 292.0 bytes

# %%
df.isnull().sum()
# Out:
# Customer    0
# Phone       0
# Product     0
# Price       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Customer"] = df["Customer"].str.title()
df["Phone"] = df["Phone"].str.replace(" ", "")

# %%
df.head()
# Out:
#      Customer        Phone      Product  Price
# 0  John Smith  07123456789    screw 5mm    0.1
# 1  Smith John   7123456789   5 mm screw    0.1
# 2     J Smith  07123456789  Screw (5mm)    0.1
# 3  Mary Jones  07222333444    bolt 10mm    0.2
# 4  Mary Jones  07222333444    10mm bolt    0.2

# %%
df.to_csv("clean_customer_data.csv", index=False)
